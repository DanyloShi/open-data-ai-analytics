# %%
import sys
from pathlib import Path

sys.path.append(str(Path().resolve().parent))

from src.data_load import load_data
from src.data_quality_analysis import quality_report

# %%
df = load_data()
quality_report(df)
# Out:
# /Users/khomyshyn/Library/Mobile Documents/com~apple~CloudDocs/Універ/VI семестр/Середовища та компоненти розробки у моделюванні та аналізі даних/src/data_load.py:9: DtypeWarning: Columns (0: city_id, 1: aqi, 2: pm25) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(DATA_PATH)
# {'shape': (6927785, 4),
#  'columns': ['city_id', 'aqi', 'pm25', 'logged_at'],
#  'missing_by_column': {'city_id': 0,
#   'aqi': 66221,
#   'pm25': 106736,
#   'logged_at': 0},
#  'duplicate_rows': 2572,
#  'dtypes': {'city_id': 'object',
#   'aqi': 'object',
#   'pm25': 'object',
#   'logged_at': 'str'}}
